# %%
import pandas as pd
from sklearn.cluster import KMeans

value_system_df = pd.read_csv('ESS/Country/PVS/ESS_PVS_4_val_3_act.csv', sep=',', na_values=[''], quotechar='"')
value_system_df
# Out:
#    country  P__Self-Transcendence__Self-Transcendence  \
# 0       AT                                        0.5
# 1       BE                                        0.5
# 2       BG                                        0.5
# 3       CH                                        0.5
# 4       CY                                        0.5
# 5       CZ                                        0.5
# 6       DE                                        0.5
# 7       DK                                        0.5
# 8       EE                                        0.5
# 9       ES                                        0.5
# 10      FI                                        0.5
# 11      FR                                        0.5
# 12      GB                                        0.5
# 13      HR                                        0.5
# 14      HU                                        0.5
# 15      IE                                        0.5
# 16      IS                                        0.5
# 17      IT                                        0.5
# 18      LT                                        0.5
# 19      LV                                        0.5
# 20      ME                                        0.5
# 21      NL                                        0.5
# 22      NO                                        0.5
# 23      PL                                        0.5
# 24      PT                                        0.5
# 25      RS                                        0.5
# 26      SE                                        0.5
# 27      SI                                        0.5
# 28      SK                                        0.5
#
#     P__Self-Transcendence__Conservation  \
# 0                              0.792876
# 1                              0.810912
# 2                              0.562925
# 3                              0.878006
# 4                              0.642504
# 5                              0.591214
# 6                              0.821407
# 7                              0.841206
# 8                              0.703203
# 9                              0.682850
# 10                             0.772969
# 11                             0.776529
# 12                             0.751139
# 13                             0.703165
# 14                             0.747536
# 15                             0.703876
# 16                             0.857179
# 17                             0.551578
# 18                             0.461267
# 19                             0.673639
# 20                             0.632625
# 21                             0.878447
# 22                             0.777935
# 23                             0.597639
# 24                             0.814839
# 25                             0.624280
# 26                             0.844898
# 27                             0.686232
# 28                             0.534329
#
#     P__Self-Transcendence__Self-Enhancement  \
# 0                                  1.000000
# 1                                  1.000000
# 2                                  0.938755
# 3                                  1.000000
# 4                                  1.000000
# 5                                  1.000000
# 6                                  1.000000
# 7                                  1.000000
# 8                                  1.000000
# 9                                  1.000000
# 10                                 1.000000
# 11                                 1.000000
# 12                                 1.000000
# 13                                 1.000000
# 14                                 1.000000
# 15                                 1.000000
# 16                                 1.000000
# 17                                 0.950912
# 18                                 0.961267
# 19                                 1.000000
# 20                                 1.000000
# 21                                 1.000000
# 22                                 1.000000
# 23                                 1.000000
# 24                                 1.000000
# 25                                 1.000000
# 26                                 1.000000
# 27                                 1.000000
# 28                                 1.000000
#
#     P__Self-Transcendence__Openness to Change  \
# 0                                    0.927847
# 1                                    0.821111
# 2                                    1.000000
# 3                                    0.795049
# 4                                    0.884290
# 5                                    0.854741
# 6                                    0.827261
# 7                                    0.797453
# 8                                    0.832506
# 9                                    0.812957
# 10                                   0.771728
# 11                                   0.780830
# 12                                   0.821919
# 13                                   0.941308
# 14                                   0.926678
# 15                                   0.839381
# 16                                   0.780522
# 17                                   1.000000
# 18                                   0.940521
# 19                                   0.810069
# 20                                   0.916568
# 21                                   0.782635
# 22                                   0.823794
# 23                                   0.981284
# 24                                   0.832902
# 25                                   0.948691
# 26                                   0.788172
# 27                                   0.857378
# 28                                   0.914973
#
#     P__Conservation__Self-Transcendence  P__Conservation__Conservation  \
# 0                              0.207124                            0.5
# 1                              0.189088                            0.5
# 2                              0.437075                            0.5
# 3                              0.121994                            0.5
# 4                              0.357496                            0.5
# 5                              0.408786                            0.5
# 6                              0.178593                            0.5
# 7                              0.158794                            0.5
# 8                              0.296797                            0.5
# 9                              0.317150                            0.5
# 10                             0.227031                            0.5
# 11                             0.223471                            0.5
# 12                             0.248861                            0.5
# 13                             0.296835                            0.5
# 14                             0.252464                            0.5
# 15                             0.296124                            0.5
# 16                             0.142821                            0.5
# 17                             0.448422                            0.5
# 18                             0.538733                            0.5
# 19                             0.326361                            0.5
# 20                             0.367375                            0.5
# 21                             0.121553                            0.5
# 22                             0.222065                            0.5
# 23                             0.402361                            0.5
# 24                             0.185161                            0.5
# 25                             0.375720                            0.5
# 26                             0.155102                            0.5
# 27                             0.313768                            0.5
# 28                             0.465671                            0.5
#
#     P__Conservation__Self-Enhancement  P__Conservation__Openness to Change  \
# 0                            0.707124                             0.634972
# 1                            0.689088                             0.510199
# 2                            0.875830                             0.937075
# 3                            0.621994                             0.417042
# 4                            0.857496                             0.741786
# 5                            0.908786                             0.763527
# 6                            0.678593                             0.505854
# 7                            0.658794                             0.456247
# 8                            0.796797                             0.629303
# 9                            0.817150                             0.630107
# 10                           0.727031                             0.498759
# 11                           0.723471                             0.504300
# 12                           0.748861                             0.570780
# 13                           0.796835                             0.738143
# 14                           0.752464                             0.679141
# 15                           0.796124                             0.635505
# 16                           0.642821                             0.423343
# 17                           0.899334                             0.948422
# 18                           1.000000                             0.979254
# 19                           0.826361                             0.636431
# 20                           0.867375                             0.783943
# 21                           0.621553                             0.404188
# 22                           0.722065                             0.545859
# 23                           0.902361                             0.883645
# 24                           0.685161                             0.518063
# 25                           0.875720                             0.824411
# 26                           0.655102                             0.443273
# 27                           0.813768                             0.671146
# 28                           0.965671                             0.880644
#
#     P__Self-Enhancement__Self-Transcendence  ...  \
# 0                                  0.000000  ...
# 1                                  0.000000  ...
# 2                                  0.061245  ...
# 3                                  0.000000  ...
# 4                                  0.000000  ...
# 5                                  0.000000  ...
# 6                                  0.000000  ...
# 7                                  0.000000  ...
# 8                                  0.000000  ...
# 9                                  0.000000  ...
# 10                                 0.000000  ...
# 11                                 0.000000  ...
# 12                                 0.000000  ...
# 13                                 0.000000  ...
# 14                                 0.000000  ...
# 15                                 0.000000  ...
# 16                                 0.000000  ...
# 17                                 0.049088  ...
# 18                                 0.038733  ...
# 19                                 0.000000  ...
# 20                                 0.000000  ...
# 21                                 0.000000  ...
# 22                                 0.000000  ...
# 23                                 0.000000  ...
# 24                                 0.000000  ...
# 25                                 0.000000  ...
# 26                                 0.000000  ...
# 27                                 0.000000  ...
# 28                                 0.000000  ...
#
#     VA__Self-Transcendence__lgbt_freedom  VA__Conservation__immigration  \
# 0                               0.467343                       0.001850
# 1                               0.525502                      -0.004670
# 2                              -0.001732                      -0.070180
# 3                               0.495349                      -0.052575
# 4                               0.113924                      -0.052830
# 5                               0.208400                      -0.048739
# 6                               0.499451                      -0.020762
# 7                               0.567591                      -0.014387
# 8                               0.130385                      -0.004197
# 9                               0.456660                       0.032378
# 10                              0.427338                      -0.004658
# 11                              0.533558                      -0.000319
# 12                              0.479550                       0.008436
# 13                              0.152051                      -0.010241
# 14                             -0.033549                      -0.034599
# 15                              0.460450                       0.033663
# 16                              0.631555                      -0.079041
# 17                              0.273446                      -0.031280
# 18                             -0.090052                       0.052308
# 19                              0.142307                       0.032060
# 20                             -0.037965                      -0.060443
# 21                              0.603732                      -0.026362
# 22                              0.578813                      -0.001137
# 23                              0.134385                       0.069572
# 24                              0.439046                      -0.019848
# 25                             -0.071151                      -0.075758
# 26                              0.580772                      -0.025997
# 27                              0.245220                      -0.020067
# 28                             -0.016654                      -0.154562
#
#     VA__Conservation__lgbt_adopt  VA__Conservation__lgbt_freedom  \
# 0                       0.005835                        0.018843
# 1                      -0.029749                       -0.051818
# 2                      -0.206347                       -0.001296
# 3                      -0.045862                       -0.143138
# 4                      -0.126152                        0.050680
# 5                      -0.070234                        0.128020
# 6                      -0.032172                       -0.059551
# 7                      -0.059662                       -0.112737
# 8                      -0.043636                        0.028060
# 9                       0.096514                        0.121253
# 10                     -0.007260                       -0.019299
# 11                     -0.010235                       -0.024604
# 12                      0.016799                        0.030614
# 13                     -0.073425                        0.044084
# 14                     -0.045856                       -0.005259
# 15                      0.055025                        0.100521
# 16                     -0.140376                       -0.161547
# 17                     -0.113291                        0.217171
# 18                     -0.415310                       -0.106218
# 19                     -0.080296                        0.041830
# 20                     -0.158901                       -0.018769
# 21                     -0.134969                       -0.183398
# 22                     -0.003357                       -0.005259
# 23                     -0.250687                        0.085740
# 24                     -0.013648                       -0.042696
# 25                     -0.208680                       -0.038186
# 26                     -0.084045                       -0.126359
# 27                     -0.034705                        0.070182
# 28                     -0.260274                       -0.014245
#
#     VA__Self-Enhancement__immigration  VA__Self-Enhancement__lgbt_adopt  \
# 0                           -0.029283                         -0.092377
# 1                           -0.036312                         -0.231323
# 2                            0.070494                          0.207271
# 3                           -0.128261                         -0.111884
# 4                            0.112559                          0.268777
# 5                            0.088406                          0.127396
# 6                           -0.129053                         -0.199978
# 7                           -0.054792                         -0.227223
# 8                            0.018156                          0.188777
# 9                           -0.122969                         -0.366551
# 10                          -0.094328                         -0.146999
# 11                          -0.006161                         -0.197878
# 12                          -0.114149                         -0.227318
# 13                           0.026404                          0.189314
# 14                           0.155223                          0.205722
# 15                          -0.141412                         -0.231147
# 16                          -0.234205                         -0.415941
# 17                           0.031476                          0.114000
# 18                          -0.050459                          0.400633
# 19                          -0.112681                          0.282218
# 20                           0.110796                          0.291278
# 21                          -0.062704                         -0.321027
# 22                          -0.101996                         -0.301247
# 23                          -0.093091                          0.335434
# 24                          -0.151553                         -0.104216
# 25                           0.121959                          0.335943
# 26                          -0.091420                         -0.295554
# 27                           0.064254                          0.111125
# 28                           0.200001                          0.336792
#
#     VA__Self-Enhancement__lgbt_freedom  VA__Openness to Change__immigration  \
# 0                            -0.298339                            -0.018438
# 1                            -0.402928                            -0.006376
# 2                             0.001302                             0.093418
# 3                            -0.349196                            -0.001107
# 4                            -0.107978                             0.059028
# 5                            -0.232213                             0.039673
# 6                            -0.370167                            -0.024311
# 7                            -0.429356                            -0.003254
# 8                            -0.121394                             0.005542
# 9                            -0.460506                            -0.031351
# 10                           -0.390770                            -0.004168
# 11                           -0.475669                            -0.000431
# 12                           -0.414251                            -0.026429
# 13                           -0.113662                             0.019158
# 14                            0.023594                             0.100093
# 15                           -0.422266                            -0.046450
# 16                           -0.478674                             0.004241
# 17                           -0.218529                             0.039190
# 18                            0.102464                            -0.046195
# 19                           -0.147020                            -0.028447
# 20                            0.034405                             0.071908
# 21                           -0.436215                             0.002283
# 22                           -0.471923                            -0.021965
# 23                           -0.114725                            -0.085525
# 24                           -0.326016                            -0.032696
# 25                            0.061473                             0.094958
# 26                           -0.444358                            -0.002069
# 27                           -0.224725                             0.025927
# 28                            0.018433                             0.135261
#
#     VA__Openness to Change__lgbt_adopt  VA__Openness to Change__lgbt_freedom
# 0                            -0.058165                             -0.187847
# 1                            -0.040622                             -0.070756
# 2                             0.274675                              0.001726
# 3                            -0.000966                             -0.003015
# 4                             0.140951                             -0.056626
# 5                             0.057170                             -0.104207
# 6                            -0.037672                             -0.069733
# 7                            -0.013494                             -0.025498
# 8                             0.057617                             -0.037051
# 9                            -0.093453                             -0.117407
# 10                           -0.006496                             -0.017268
# 11                           -0.013846                             -0.033284
# 12                           -0.052631                             -0.095912
# 13                            0.137363                             -0.082472
# 14                            0.132657                              0.015214
# 15                           -0.075927                             -0.138705
# 16                            0.007531                              0.008667
# 17                            0.141940                             -0.272088
# 18                            0.366778                              0.093806
# 19                            0.071248                             -0.037116
# 20                            0.189041                              0.022329
# 21                            0.011687                              0.015881
# 22                           -0.064875                             -0.101631
# 23                            0.308170                             -0.105400
# 24                           -0.022483                             -0.070334
# 25                            0.261568                              0.047863
# 26                           -0.006688                             -0.010055
# 27                            0.044839                             -0.090677
# 28                            0.227773                              0.012466
#
# [29 rows x 29 columns]

# %%
abstracted_system_df = pd.read_csv('ESS/Country/PVS/ESS_PVS_10_val_2_act.csv', sep=',', na_values=[''], quotechar='"')
abstracted_system_df
# Out:
#    country  P__Universalism__Universalism  P__Universalism__Benevolence  \
# 0       AT                            0.5                      0.439349
# 1       BE                            0.5                      0.441223
# 2       BG                            0.5                      0.385816
# 3       CH                            0.5                      0.436463
# 4       CY                            0.5                      0.470375
# 5       CZ                            0.5                      0.477951
# 6       DE                            0.5                      0.444776
# 7       DK                            0.5                      0.396738
# 8       EE                            0.5                      0.474894
# 9       ES                            0.5                      0.472105
# 10      FI                            0.5                      0.477220
# 11      FR                            0.5                      0.484639
# 12      GB                            0.5                      0.444196
# 13      HR                            0.5                      0.461647
# 14      HU                            0.5                      0.431455
# 15      IE                            0.5                      0.463682
# 16      IS                            0.5                      0.448187
# 17      IT                            0.5                      0.479471
# 18      LT                            0.5                      0.526928
# 19      LV                            0.5                      0.479471
# 20      ME                            0.5                      0.431501
# 21      NL                            0.5                      0.449956
# 22      NO                            0.5                      0.418317
# 23      PL                            0.5                      0.492553
# 24      PT                            0.5                      0.444485
# 25      RS                            0.5                      0.440447
# 26      SE                            0.5                      0.460369
# 27      SI                            0.5                      0.517507
# 28      SK                            0.5                      0.531749
#
#     P__Universalism__Tradition  P__Universalism__Conformity  \
# 0                     0.703331                     0.722122
# 1                     0.625068                     0.729282
# 2                     0.515147                     0.568946
# 3                     0.676963                     0.816568
# 4                     0.556057                     0.775523
# 5                     0.627232                     0.633027
# 6                     0.673733                     0.797575
# 7                     0.693305                     0.646953
# 8                     0.676228                     0.707138
# 9                     0.606976                     0.705646
# 10                    0.714356                     0.706067
# 11                    0.655078                     0.783897
# 12                    0.655838                     0.736748
# 13                    0.633073                     0.681139
# 14                    0.606303                     0.709556
# 15                    0.620792                     0.744602
# 16                    0.719446                     0.798822
# 17                    0.522919                     0.614665
# 18                    0.508926                     0.623350
# 19                    0.601574                     0.770458
# 20                    0.594308                     0.625977
# 21                    0.699299                     0.766258
# 22                    0.732603                     0.608508
# 23                    0.610015                     0.616319
# 24                    0.613854                     0.785188
# 25                    0.573961                     0.649756
# 26                    0.710967                     0.778698
# 27                    0.595210                     0.726452
# 28                    0.573187                     0.613446
#
#     P__Universalism__Security  P__Universalism__Power  \
# 0                    0.504447                0.885860
# 1                    0.622781                0.941223
# 2                    0.370162                0.861348
# 3                    0.628700                0.936463
# 4                    0.469623                0.969623
# 5                    0.347955                0.757128
# 6                    0.602473                0.944776
# 7                    0.648240                0.896738
# 8                    0.534182                0.974894
# 9                    0.548970                0.972105
# 10                   0.616419                0.977220
# 11                   0.615722                0.984639
# 12                   0.563688                0.944196
# 13                   0.524988                0.925868
# 14                   0.397183                0.820360
# 15                   0.540901                0.963682
# 16                   0.675686                0.948187
# 17                   0.428150                0.815382
# 18                   0.351860                0.769727
# 19                   0.466166                0.966166
# 20                   0.461635                0.931501
# 21                   0.666258                0.949956
# 22                   0.639556                0.918317
# 23                   0.468430                0.816977
# 24                   0.558585                0.944485
# 25                   0.451450                0.940447
# 26                   0.710113                0.960369
# 27                   0.521704                1.000000
# 28                   0.423147                0.855983
#
#     P__Universalism__Achievement  P__Universalism__Hedonism  \
# 0                       0.739503                   0.673828
# 1                       0.760563                   0.619188
# 2                       0.550557                   0.819098
# 3                       0.803766                   0.623315
# 4                       0.849743                   0.848992
# 5                       0.801592                   0.709965
# 6                       0.815840                   0.679855
# 7                       0.798197                   0.590901
# 8                       0.848034                   0.763895
# 9                       0.867374                   0.724841
# 10                      0.880388                   0.655164
# 11                      0.903663                   0.632759
# 12                      0.793838                   0.753970
# 13                      0.750291                   0.739250
# 14                      0.652193                   0.569707
# 15                      0.818042                   0.807485
# 16                      0.900423                   0.656773
# 17                      0.612275                   0.904387
# 18                      0.658453                   0.780191
# 19                      0.836767                   0.735908
# 20                      0.704381                   0.832031
# 21                      0.778528                   0.634093
# 22                      0.825270                   0.718222
# 23                      0.755300                   0.968430
# 24                      0.704004                   0.629698
# 25                      0.692106                   0.830335
# 26                      0.909891                   0.670225
# 27                      0.682069                   0.708139
# 28                      0.764467                   0.841843
#
#     P__Universalism__Stimulation  ...  VA__Power__immigration  \
# 0                       0.939349  ...               -0.027306
# 1                       0.806055  ...               -0.038514
# 2                       0.870162  ...                0.076549
# 3                       0.839023  ...               -0.135462
# 4                       0.948578  ...                0.103469
# 5                       0.847955  ...                0.039908
# 6                       0.868063  ...               -0.130618
# 7                       0.781803  ...               -0.053010
# 8                       0.864831  ...                0.017993
# 9                       0.848431  ...               -0.116937
# 10                      0.781100  ...               -0.093882
# 11                      0.834004  ...               -0.006902
# 12                      0.796187  ...               -0.110411
# 13                      0.961647  ...                0.026638
# 14                      0.897183  ...                0.134448
# 15                      0.837982  ...               -0.134983
# 16                      0.776459  ...               -0.223131
# 17                      0.928150  ...                0.022460
# 18                      0.851860  ...               -0.026743
# 19                      0.846209  ...               -0.110188
# 20                      0.876953  ...                0.107016
# 21                      0.800438  ...               -0.068116
# 22                      0.803651  ...               -0.092742
# 23                      0.921692  ...               -0.048258
# 24                      0.827684  ...               -0.172244
# 25                      0.896350  ...                0.123031
# 26                      0.846174  ...               -0.087659
# 27                      0.868376  ...                0.074085
# 28                      0.923147  ...                0.124399
#
#     VA__Power__lgbt_freedom  VA__Achievement__immigration  \
# 0                 -0.280020                     -0.009092
# 1                 -0.432820                     -0.013629
# 2                 -0.002990                     -0.018587
# 3                 -0.364803                     -0.066181
# 4                 -0.107008                      0.057843
# 5                 -0.103210                      0.052676
# 6                 -0.373326                     -0.065373
# 7                 -0.412298                     -0.031973
# 8                 -0.119215                      0.009912
# 9                 -0.440773                     -0.074624
# 10                -0.390854                     -0.062166
# 11                -0.480228                     -0.004945
# 12                -0.401324                     -0.048812
# 13                -0.112105                      0.007777
# 14                 0.018798                      0.028966
# 15                -0.404187                     -0.063743
# 16                -0.454767                     -0.179835
# 17                -0.158993                     -0.003536
# 18                 0.053832                     -0.007912
# 19                -0.144271                     -0.061012
# 20                 0.030978                      0.019520
# 21                -0.472300                     -0.025380
# 22                -0.430172                     -0.057680
# 23                -0.060457                     -0.027058
# 24                -0.370023                     -0.029509
# 25                 0.060661                      0.014170
# 26                -0.426118                     -0.069952
# 27                -0.259485                      0.003013
# 28                 0.009547                      0.067228
#
#     VA__Achievement__lgbt_freedom  VA__Hedonism__immigration  \
# 0                       -0.093233                  -0.000918
# 1                       -0.153168                   0.005844
# 2                        0.000726                   0.063616
# 3                       -0.178228                   0.028032
# 4                       -0.059821                   0.057557
# 5                       -0.136230                   0.026366
# 6                       -0.186844                   0.003440
# 7                       -0.248679                   0.012281
# 8                       -0.065674                   0.004553
# 9                       -0.281283                  -0.017040
# 10                      -0.258811                   0.011605
# 11                      -0.344058                   0.001602
# 12                      -0.177423                  -0.032479
# 13                      -0.032727                   0.006590
# 14                       0.004050                  -0.022772
# 15                      -0.190867                  -0.058579
# 16                      -0.366525                   0.041022
# 17                       0.025034                   0.033852
# 18                       0.015926                  -0.028514
# 19                      -0.079884                  -0.022682
# 20                       0.005651                   0.068696
# 21                      -0.175976                   0.010627
# 22                      -0.267541                  -0.017342
# 23                      -0.033899                  -0.100314
# 24                      -0.063393                   0.014594
# 25                       0.006987                   0.074763
# 26                      -0.340044                   0.014117
# 27                      -0.010551                   0.008840
# 28                       0.005159                   0.115566
#
#     VA__Hedonism__lgbt_freedom  VA__Stimulation__immigration  \
# 0                    -0.009416                     -0.033963
# 1                     0.065674                     -0.019895
# 2                    -0.002485                      0.079247
# 3                     0.075492                     -0.084589
# 4                    -0.059526                      0.095459
# 5                    -0.068187                      0.065989
# 6                     0.009833                     -0.091799
# 7                     0.095521                     -0.028473
# 8                    -0.030165                      0.010982
# 9                    -0.064228                     -0.066971
# 10                    0.048313                     -0.029645
# 11                    0.111498                     -0.003261
# 12                   -0.118054                     -0.049774
# 13                   -0.027735                      0.030482
# 14                   -0.003184                      0.182635
# 15                   -0.175405                     -0.073496
# 16                    0.083608                     -0.067467
# 17                   -0.239636                      0.036893
# 18                    0.057396                     -0.040643
# 19                   -0.029698                     -0.064600
# 20                    0.019886                      0.086002
# 21                    0.073687                     -0.030842
# 22                   -0.080439                     -0.049533
# 23                   -0.125673                     -0.084250
# 24                    0.031352                     -0.102918
# 25                    0.036862                      0.103701
# 26                    0.068626                     -0.047601
# 27                   -0.030964                      0.044661
# 28                    0.008869                      0.166358
#
#     VA__Stimulation__lgbt_freedom  VA__Self-Direction__immigration  \
# 0                       -0.348285                         0.013657
# 1                       -0.223587                         0.012515
# 2                       -0.003096                         0.018444
# 3                       -0.227800                         0.087817
# 4                       -0.098724                        -0.041347
# 5                       -0.170660                        -0.040055
# 6                       -0.262374                         0.074492
# 7                       -0.221456                         0.024980
# 8                       -0.072764                        -0.007153
# 9                       -0.252436                         0.041395
# 10                      -0.123419                         0.030329
# 11                      -0.226918                         0.002485
# 12                      -0.180920                         0.047699
# 13                      -0.128281                        -0.008249
# 14                       0.025535                        -0.081434
# 15                      -0.220074                         0.052633
# 16                      -0.137505                         0.095830
# 17                      -0.261166                        -0.005921
# 18                       0.081810                         0.011167
# 19                      -0.084582                         0.044353
# 20                       0.024895                        -0.028850
# 21                      -0.213850                         0.038463
# 22                      -0.229754                         0.043200
# 23                      -0.105548                         0.020805
# 24                      -0.221093                         0.070872
# 25                       0.051130                        -0.016145
# 26                      -0.231395                         0.053516
# 27                      -0.156426                        -0.022829
# 28                       0.012767                        -0.072021
#
#     VA__Self-Direction__lgbt_freedom
# 0                           0.140047
# 1                           0.140644
# 2                          -0.000720
# 3                           0.236496
# 4                           0.042761
# 5                           0.103591
# 6                           0.212909
# 7                           0.194291
# 8                           0.047394
# 9                           0.156033
# 10                          0.126266
# 11                          0.172922
# 12                          0.173376
# 13                          0.034716
# 14                         -0.011386
# 15                          0.157602
# 16                          0.195313
# 17                          0.041914
# 18                         -0.022478
# 19                          0.058073
# 20                         -0.008351
# 21                          0.266691
# 22                          0.200379
# 23                          0.026065
# 24                          0.152250
# 25                         -0.007960
# 26                          0.260145
# 27                          0.079961
# 28                         -0.005527
#
# [29 rows x 121 columns]

# %% [markdown]
# ## Notes
#
# - "Immigration" means "Immigration bad or good for country's economy", where a higher value means **good**.
# - "lgbt_freedom" means "Gay men and lesbians should be free to live life as they wish", where a higher value means **yes**
# - "lgbt_adopt" means "Gay men and lesbians should have the same rights to adopt children as straight couples", where a higher value means **yes**
#
# - If no country is specified, plots are over **all** countries

# %% [markdown]
# ## Step 1: Understand the relationship of action judgements
# - An action judgement states: If the action is taken, then to what extent will my value be promoted or demoted? (In the opinion of the agent)
#
# ### Key Conclusions
# - Polarising actions have very strong, differing promotion and demotion between agents. We can see that Immigration is the most polarising action.
#
# - Over all agents, "Immigration" shows a medium-strength correlation between certain values and actions. There are more extreme views portrayed, showing an increased level of polarisation.
# - For LGBT rights and adoption, there is no strong correlation between actions and values. There is no overall trend, and the actions are not very polarising.

# %%
# Find all columns that start with "P__"
pref_cols = pd.DataFrame(value_system_df.filter(regex="^P__"))
# Remove all cols that have the same two values (P__Universalism__Universalism, P__Benevolence__Benevolence, etc.)
for col in pref_cols.columns:
    col_split = col.split("__")
    if len(col_split) == 3 and col_split[1] == col_split[2]:
        pref_cols = pref_cols.drop(col, axis=1)
    else:
        # Not dropped, so drop the symmetrical col (P__A__B == P__B__A)
        symmetrical_col = "P__"+ col_split[2] + "__" + col_split[1]
        if col in pref_cols.columns:
            pref_cols = pref_cols.drop(columns=[symmetrical_col])
print("len of pref_cols: ", len(pref_cols.keys()))

abstracted_pref_cols = pd.DataFrame(abstracted_system_df.filter(regex="^P__"))
# Remove all cols that have the same two values (P__Universalism__Universalism, P__Benevolence__Benevolence, etc.)
for col in abstracted_pref_cols.columns:
    col_split = col.split("__")
    if len(col_split) == 3 and col_split[1] == col_split[2]:
        print("Dropping: ", col)
        abstracted_pref_cols = abstracted_pref_cols.drop(col, axis=1)
    else:
        print("Not Dropping: ", col)
        # Not dropped, so drop the symmetrical col (P__A__B == P__B__A)
        symmetrical_col = "P__"+ col_split[2] + "__" + col_split[1]
        if col in abstracted_pref_cols.columns:
            abstracted_pref_cols = abstracted_pref_cols.drop(columns=[symmetrical_col])
print("len of abstracted: ", len(abstracted_pref_cols.keys()))
# Out:
# len of pref_cols:  6
# Dropping:  P__Universalism__Universalism
# Not Dropping:  P__Universalism__Benevolence
# Not Dropping:  P__Universalism__Tradition
# Not Dropping:  P__Universalism__Conformity
# Not Dropping:  P__Universalism__Security
# Not Dropping:  P__Universalism__Power
# Not Dropping:  P__Universalism__Achievement
# Not Dropping:  P__Universalism__Hedonism
# Not Dropping:  P__Universalism__Stimulation
# Not Dropping:  P__Universalism__Self-Direction
# Not Dropping:  P__Benevolence__Universalism
# Dropping:  P__Benevolence__Benevolence
# Not Dropping:  P__Benevolence__Tradition
# Not Dropping:  P__Benevolence__Conformity
# Not Dropping:  P__Benevolence__Security
# Not Dropping:  P__Benevolence__Power
# Not Dropping:  P__Benevolence__Achievement
# Not Dropping:  P__Benevolence__Hedonism
# Not Dropping:  P__Benevolence__Stimulation
# Not Dropping:  P__Benevolence__Self-Direction
# Not Dropping:  P__Tradition__Universalism
# Not Dropping:  P__Tradition__Benevolence
# Dropping:  P__Tradition__Tradition
# Not Dropping:  P__Tradition__Conformity
# Not Dropping:  P__Tradition__Security
# Not Dropping:  P__Tradition__Power
# Not Dropping:  P__Tradition__Achievement
# Not Dropping:  P__Tradition__Hedonism
# Not Dropping:  P__Tradition__Stimulation
# Not Dropping:  P__Tradition__Self-Direction
# Not Dropping:  P__Conformity__Universalism
# Not Dropping:  P__Conformity__Benevolence
# Not Dropping:  P__Conformity__Tradition
# Dropping:  P__Conformity__Conformity
# Not Dropping:  P__Conformity__Security
# Not Dropping:  P__Conformity__Power
# Not Dropping:  P__Conformity__Achievement
# Not Dropping:  P__Conformity__Hedonism
# Not Dropping:  P__Conformity__Stimulation
# Not Dropping:  P__Conformity__Self-Direction
# Not Dropping:  P__Security__Universalism
# Not Dropping:  P__Security__Benevolence
# Not Dropping:  P__Security__Tradition
# Not Dropping:  P__Security__Conformity
# Dropping:  P__Security__Security
# Not Dropping:  P__Security__Power
# Not Dropping:  P__Security__Achievement
# Not Dropping:  P__Security__Hedonism
# Not Dropping:  P__Security__Stimulation
# Not Dropping:  P__Security__Self-Direction
# Not Dropping:  P__Power__Universalism
# Not Dropping:  P__Power__Benevolence
# Not Dropping:  P__Power__Tradition
# Not Dropping:  P__Power__Conformity
# Not Dropping:  P__Power__Security
# Dropping:  P__Power__Power
# Not Dropping:  P__Power__Achievement
# Not Dropping:  P__Power__Hedonism
# Not Dropping:  P__Power__Stimulation
# Not Dropping:  P__Power__Self-Direction
# Not Dropping:  P__Achievement__Universalism
# Not Dropping:  P__Achievement__Benevolence
# Not Dropping:  P__Achievement__Tradition
# Not Dropping:  P__Achievement__Conformity
# Not Dropping:  P__Achievement__Security
# Not Dropping:  P__Achievement__Power
# Dropping:  P__Achievement__Achievement
# Not Dropping:  P__Achievement__Hedonism
# Not Dropping:  P__Achievement__Stimulation
# Not Dropping:  P__Achievement__Self-Direction
# Not Dropping:  P__Hedonism__Universalism
# Not Dropping:  P__Hedonism__Benevolence
# Not Dropping:  P__Hedonism__Tradition
# Not Dropping:  P__Hedonism__Conformity
# Not Dropping:  P__Hedonism__Security
# Not Dropping:  P__Hedonism__Power
# Not Dropping:  P__Hedonism__Achievement
# Dropping:  P__Hedonism__Hedonism
# Not Dropping:  P__Hedonism__Stimulation
# Not Dropping:  P__Hedonism__Self-Direction
# Not Dropping:  P__Stimulation__Universalism
# Not Dropping:  P__Stimulation__Benevolence
# Not Dropping:  P__Stimulation__Tradition
# Not Dropping:  P__Stimulation__Conformity
# Not Dropping:  P__Stimulation__Security
# Not Dropping:  P__Stimulation__Power
# Not Dropping:  P__Stimulation__Achievement
# Not Dropping:  P__Stimulation__Hedonism
# Dropping:  P__Stimulation__Stimulation
# Not Dropping:  P__Stimulation__Self-Direction
# Not Dropping:  P__Self-Direction__Universalism
# Not Dropping:  P__Self-Direction__Benevolence
# Not Dropping:  P__Self-Direction__Tradition
# Not Dropping:  P__Self-Direction__Conformity
# Not Dropping:  P__Self-Direction__Security
# Not Dropping:  P__Self-Direction__Power
# Not Dropping:  P__Self-Direction__Achievement
# Not Dropping:  P__Self-Direction__Hedonism
# Not Dropping:  P__Self-Direction__Stimulation
# Dropping:  P__Self-Direction__Self-Direction
# len of abstracted:  45

# %%
stds = pref_cols.std()
stds = stds.sort_values(ascending=True)
print("Standard Deviations for each comparison: \n", stds)
# Out:
# Standard Deviations for each comparison:
#  P__Self-Transcendence__Self-Enhancement      0.015692
# P__Self-Transcendence__Openness to Change    0.071265
# P__Self-Enhancement__Openness to Change      0.081390
# P__Conservation__Self-Enhancement            0.105096
# P__Self-Transcendence__Conservation          0.112839
# P__Conservation__Openness to Change          0.172486
# dtype: float64

# %%
# There are 45 pairwise comparisons, look at top 10 for each (most nothing, most strong)
import matplotlib.pyplot as plt
import copy
k = 5
# Find cols that have a mean closest to 0 or 1, find the absolute difference to either 0 or 1 (depending on which side of 0.5 they're on), and then rank the distances
high_means = pref_cols.mean(axis=0).sort_values(ascending=False)
low_means = pref_cols.mean(axis=0).sort_values(ascending=True)
# Drop all rows where value is less than 0.5
high_means = high_means[high_means >= 0.5]
low_means = low_means[low_means < 0.5]

# Find diff, so the strength will be equal
low_means = 1 - low_means
# Concat
means = pd.concat([high_means, low_means])
means = means.sort_values(ascending=False)
print(len(means))
means_keys_high = copy.copy(means.keys().tolist()[:k])
means = means.sort_values(ascending=True)
means_keys_low = means.keys().tolist()[:k]
#print("Low keys: ", means_keys_low)

fig, axes = plt.subplots(1, 2, figsize=(12, 5), gridspec_kw={"width_ratios": [1, 1]})

for col in means_keys_high:
    pref_cols.hist(col, bins=10, alpha=0.6, label=col, ax=axes[0])
axes[0].set_title(f"Dist k={k} Most Extreme Preferences", fontsize=16)
axes[0].set_xlabel('Value Preference A > B', fontsize=12)
axes[0].set_ylabel('Frequency Amongst Agents', fontsize=12)
axes[0].legend(fontsize=10)
axes[0].set_ylabel("Value", fontsize=11)
axes[0].tick_params(axis="x", rotation=45)
axes[0].grid(alpha=0.25)
axes[0].set_xlim(0, 1)

for col in means_keys_low:
    pref_cols.hist(col, bins=10, alpha=0.6, label=col, ax=axes[1])
axes[1].set_title(f"Dist k={k} Least Extreme Preferences", fontsize=16)
axes[1].set_xlabel('Value Preference A > B', fontsize=12)
axes[1].set_ylabel('Frequency Amongst Agents', fontsize=12)
axes[1].legend(fontsize=10)
axes[1].set_ylabel("Value", fontsize=11)
axes[1].tick_params(axis="x", rotation=45)
axes[1].grid(alpha=0.25)
axes[1].set_xlim(0, 1)

plt.tight_layout()
plt.show()
# Out:
# 6

# %%
# There are 45 pairwise comparisons, look at top 10 for each (most nothing, most strong)
import matplotlib.pyplot as plt
k = 3
# Find cols that have a mean closest to 0 or 1, find the absolute difference to either 0 or 1 (depending on which side of 0.5 they're on), and then rank the distances
high_means = abstracted_pref_cols.mean(axis=0).sort_values(ascending=False)
low_means = abstracted_pref_cols.mean(axis=0).sort_values(ascending=True)

# Drop all rows where the value is less than/above 0.5
high_means = high_means[high_means >= 0.5]
low_means = low_means[low_means < 0.5]

# Find diff
low_means = 1 - low_means
# Concat
means = pd.concat([high_means, low_means])
means = means.sort_values(ascending=False)
print(len(means))
means_keys_high = means.keys().tolist()[:k]
#print("High keys: ", means_keys_high)
means = means.sort_values(ascending=True)
means_keys_low = means.keys().tolist()[:k]
#print("Low keys: ", means_keys_low)

fig, axes = plt.subplots(1, 2, figsize=(12, 5), gridspec_kw={"width_ratios": [1, 1]})

for col in means_keys_high:
    abstracted_pref_cols.hist(col, bins=10, alpha=0.6, label=col, ax=axes[0])
axes[0].set_title(f"Dist k={k} Most Extreme Preferences", fontsize=16)
axes[0].set_xlabel('Value Preference A > B', fontsize=12)
axes[0].set_ylabel('Frequency Amongst Agents', fontsize=12)
axes[0].legend(fontsize=10)
axes[0].set_ylabel("Value", fontsize=11)
axes[0].tick_params(axis="x", rotation=45)
axes[0].grid(alpha=0.25)
axes[0].set_xlim(0, 1)

for col in means_keys_low:
    abstracted_pref_cols.hist(col, bins=10, alpha=0.6, label=col, ax=axes[1])
axes[1].set_title(f"Dist k={k} Least Extreme Preferences", fontsize=16)
axes[1].set_xlabel('Value Preference A > B', fontsize=12)
axes[1].set_ylabel('Frequency Amongst Agents', fontsize=12)
axes[1].legend(fontsize=10)
axes[1].set_ylabel("Value", fontsize=11)
axes[1].tick_params(axis="x", rotation=45)
axes[1].grid(alpha=0.25)
axes[1].set_xlim(0, 1)

plt.tight_layout()
plt.show()
# Out:
# 45

# %%
# Find cols that have a mean closest to 0 or 1, find the absolute difference to either 0 or 1 (depending on which side of 0.5 they're on), and then rank the distances
high_means = abstracted_pref_cols.mean(axis=0).sort_values(ascending=False)
low_means = abstracted_pref_cols.mean(axis=0).sort_values(ascending=True)

# Drop all rows where the value is less than/above 0.5, then transform
high_means = high_means[high_means >= 0.5]
low_means = low_means[low_means < 0.5]
low_means = 1-low_means
means = pd.concat([high_means, low_means])

print("mean of means is: ", sum(means)/len(means))
## plot hist of means
ax = means.plot.hist(bins=10, alpha=0.5)
# Out:
# mean of means is:  0.6867834513509875

# %% [markdown]
# ### Notes on Value Preferences
# - What happens to the performance of value aggregators when we remove the "noise" of indifferent value preferences?
# - Are the extreme value preferences reflected in our actions? Are more extreme opinions on the actions shared by agents with more extreme value preferences?
#
# **Values in Extreme Preferences suggest:**
# - *Strong preference for:* **Power**, Stimulation, Achievement
# - *Strong Preference against:* Tradition, Self-Direction, Benevolence, Security, Stimulation, **Power**

# %%
import re
import matplotlib.pyplot as plt

def _va_cols_for_topic(df, topic: str):
    # Get all VA columns for a given topic
    pattern = re.compile(rf"^VA__.*__{re.escape(topic)}$", flags=re.IGNORECASE)
    return [c for c in df.columns if pattern.match(c)]

def plot_va_topic(df, topic: str, figsize=(12, 5)):
    # Plot VA boxplot and mean by VA column for a given topic
    cols = _va_cols_for_topic(df, topic)
    if not cols:
        raise ValueError(f"No VA columns found for topic '{topic}'. Expected columns like 'VA__<Value>__{topic}'.")
    cols = sorted(cols)

    fig, axes = plt.subplots(1, 2, figsize=figsize, gridspec_kw={"width_ratios": [2, 1]})

    df[cols].boxplot(ax=axes[0], patch_artist=True, boxprops=dict(facecolor="#b7e4c7"))
    axes[0].set_title(f"VA Columns for {topic}", fontsize=14)
    axes[0].set_ylabel("Value", fontsize=11)
    axes[0].tick_params(axis="x", rotation=90)
    axes[0].set_ylim(-1, 1)
    axes[0].grid(alpha=0.25)


    means = df[cols].mean(numeric_only=True).sort_values(ascending=False)
    print(means)
    axes[1].barh(means.index, means.values, color="#74c0fc", edgecolor="black")
    axes[1].set_title("Mean by VA column", fontsize=12)
    axes[1].set_xlabel("Mean", fontsize=11)
    axes[1].invert_yaxis()
    axes[1].set_xlim(-1, 1)
    axes[1].grid(axis="x", alpha=0.25)

    plt.tight_layout()
    plt.show()

    # Save cols to a .csv
    cols_df = pd.DataFrame(df[cols])
    cols_df.to_csv(f"VA_{topic}.csv", index=False)

plot_va_topic(value_system_df, "immigration")
# Out:
# VA__Self-Transcendence__immigration    0.035380
# VA__Openness to Change__immigration    0.010740
# VA__Conservation__immigration         -0.020082
# VA__Self-Enhancement__immigration     -0.026038
# dtype: float64

# %%
plot_va_topic(abstracted_system_df, "immigration")
# Out:
# VA__Benevolence__immigration       0.028097
# VA__Universalism__immigration      0.022278
# VA__Self-Direction__immigration    0.015884
# VA__Hedonism__immigration          0.010446
# VA__Stimulation__immigration      -0.002321
# VA__Tradition__immigration        -0.004156
# VA__Security__immigration         -0.006376
# VA__Conformity__immigration       -0.012575
# VA__Achievement__immigration      -0.022755
# VA__Power__immigration            -0.028521
# dtype: float64

# %% [markdown]
# ### Notes: Immigration is good for the economony Action
# - Medium-Strength (+/- 0.5) matching Schwartz Values
#     - Self-Direction, Stimulation, Power, Benevolence, Universalism

# %%
plot_va_topic(value_system_df, "lgbt_freedom")
# Out:
# VA__Self-Transcendence__lgbt_freedom    0.306749
# VA__Conservation__lgbt_freedom         -0.006117
# VA__Openness to Change__lgbt_freedom   -0.052039
# VA__Self-Enhancement__lgbt_freedom     -0.248594
# dtype: float64

# %%
plot_va_topic(abstracted_system_df, "lgbt_freedom")
# Out:
# VA__Benevolence__lgbt_freedom       0.209776
# VA__Universalism__lgbt_freedom      0.166056
# VA__Self-Direction__lgbt_freedom    0.109083
# VA__Security__lgbt_freedom          0.078426
# VA__Tradition__lgbt_freedom         0.012172
# VA__Hedonism__lgbt_freedom         -0.009592
# VA__Conformity__lgbt_freedom       -0.051602
# VA__Achievement__lgbt_freedom      -0.126942
# VA__Stimulation__lgbt_freedom      -0.145034
# VA__Power__lgbt_freedom            -0.242342
# dtype: float64

# %% [markdown]
# ### Notes: LGBT Rights Action
# - Low-Strength correlation between values and actions, with a few agents having stronger correlations.
# - No overall large trend.

# %% [markdown]
# ### Notes: LGBT Adoption Action
# - Low-Strength correlation with no extreme positions within the entire group.

# %% [markdown]
# ### K-Means clustering/PCA analysis to find clusters of agents with similar action judgements
# - Here we are looking to find distinct clusters. An ideal scenario would be i) one large cluster, with a small opposing cluster ii) two strongly opposing clusters of similar size. iii) No clear clusters.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

def _va_cols_for_action(df: pd.DataFrame, action: str):
    suffix = f"__{action}"
    return [c for c in df.columns if c.startswith("VA__") and c.endswith(suffix)]

def PCA_per_action(df, actions=("immigration", "lgbt_freedom")):
    for action in actions:
        cols = sorted(_va_cols_for_action(df, action))
        scaler = StandardScaler()
        # take col data, and scale between 0-1, std 1, for PCA
        X = df[cols].to_numpy(dtype=float)
        X = scaler.fit_transform(X)
        pca_output = PCA(n_components=2).fit_transform(X)

        plt.figure(figsize=(6.5, 5.2))
        plt.scatter(pca_output[:, 0], pca_output[:, 1], s=55, alpha=0.85, edgecolor="white", linewidth=0.5, label=action)
        plt.title(f"PCA view of {action} action judgements")
        plt.xlabel("PC1")
        plt.ylabel("PC2")
        plt.xlim(-4, 4)
        plt.ylim(-4, 4)
        plt.grid(alpha=0.25)
        plt.legend(frameon=True)

# %%
PCA_per_action(value_system_df)

# %%
PCA_per_action(abstracted_system_df)

# %% [markdown]
# ### Step 4: Check for a principle corrolation.
# We use Pearsons correlation coefficient to show correlation here

# %%
principle_pref_df = pd.read_csv('/value_systems/ESS/Country/PriP/ESS_PriP_4_val_3_act.csv')
principle_pref_df = principle_pref_df.drop(columns=['country'])
# force egal col to be floats
principle_pref_df['Egalitarian'] = principle_pref_df['Egalitarian'].astype(float)
principle_pref_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 principle_pref_df = pd.read_csv('/value_systems/ESS/Country/PriP/ESS_PriP_4_val_3_act.csv')
#       2 principle_pref_df = principle_pref_df.drop(columns=['country'])
#       3 # force egal col to be floats
#       4 principle_pref_df['Egalitarian'] = principle_pref_df['Egalitarian'].astype(float)
#
# File ~/miniconda3/envs/HCVA-plus-plus/lib/python3.13/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/HCVA-plus-plus/lib/python3.13/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/miniconda3/envs/HCVA-plus-plus/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/HCVA-plus-plus/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~/miniconda3/envs/HCVA-plus-plus/lib/python3.13/site-packages/pandas/io/common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/value_systems/ESS/Country/PriP/ESS_PriP_4_val_3_act.csv'

# %%
value_system_df = pd.read_csv('/value_systems/ESS/Country/PVS/ESS_PVS_4_val_3_act.csv', sep=',', na_values=[''], quotechar='"')
value_system_df = value_system_df.drop(columns=['country'])
value_system_df

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cross_decomposition import CCA
from sklearn.preprocessing import StandardScaler

## Load in dataframes
# force egal col to be floats
principle_pref_df['Egalitarian'] = principle_pref_df['Egalitarian'].astype(float)
# Drop the VA cols
value_system_df = value_system_df.drop(columns=list(value_system_df.filter(regex="^VA__")))
joint_df = pd.concat([principle_pref_df, value_system_df], axis=1)

## Print out all rows that have a NaN or None value in them
joint_df = joint_df.dropna(how='any').dropna(how='any', axis=1)

prips = joint_df.iloc[:, :1]
pvs = joint_df.iloc[:, 1:]

scaler1 = StandardScaler()
scaler2 = StandardScaler()

prips_scaled = scaler1.fit_transform(prips)
pvs_scaled = scaler2.fit_transform(pvs)

X = prips_scaled
Y = pvs_scaled

cca = CCA(n_components=1)
X_c, Y_c = cca.fit_transform(X, Y)

correlation = np.corrcoef(X_c, Y_c)
print(f"Correlation between first canonical variables: {correlation}")

plt.figure(figsize=(6, 5))
plt.scatter(X_c[:, 0], Y_c[:, 0], alpha=0.6)
plt.xlabel("Canonical Variable 1 (PriPs)")
plt.ylabel("Canonical Variable 2 (P)")
plt.title("CCA: First Canonical Variables")
plt.grid(True)
plt.show()
